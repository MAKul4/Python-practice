# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
# Variable assignment

x = 5

# %%
# Output
x
# Out:
# 5

# %% [markdown]
# **Aritmetic Operations**

# %%
# Addition
x + 5
# Out:
# 10

# %%
# Subtraction

x - 3
# Out:
# 2

# %%
# Multiplication

x * 8
# Out:
# 40

# %%
# Exponentiation

x**2
# Out:
# 25

# %%
# Division

x / 5
# Out:
# 1.0

# %%
# Remainder of a division

x % 2
# Out:
# 1

# %% [markdown]
# **Type & type conversion of the variable**

# %%
type(x)
# Out:
# int

# %%
type("kaggle")
# Out:
# str

# %%
type(1.0)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
# Convert an integer, float or boolean to string
str(10)
# Out:
# '10'

# %%
str(10.19)
# Out:
# '10.19'

# %%
str(True)
# Out:
# 'True'

# %%
# Convert float to integer
int(11.5)
# Out:
# 11

# %%
# Convert integer to float

float(12)
# Out:
# 12.0

# %%
# convert variable to boolean
bool(5)
# Out:
# True

# %% [markdown]
# **String & string opertions**

# %%
# Assignment

my_sentence = "It's a wonderful day!"

# %%
# Multiplication by a number will repeat the string. 
# Notice there is no space in between two strings

my_sentence * 2
# Out:
# "It's a wonderful day!It's a wonderful day!"

# %%
# Concatenate i.e. adding a word or sentence to a string

my_sentence + "Right ?"
# Out:
# "It's a wonderful day!Right ?"

# %%
#Add a space
my_sentence + " " + "Right ?"
# Out:
# "It's a wonderful day! Right ?"

# %%
# Find a letter or word in the strign

"a" in my_sentence
# Out:
# True

# %%
"m" in my_sentence
# Out:
# False

# %%
# Indexing

my_sentence[5]
# Out:
# 'a'

# %%
my_sentence[5:10]
# Out:
# 'a won'

# %%
# string methods

# Conver to uppercase

my_sentence.upper()
# Out:
# "IT'S A WONDERFUL DAY!"

# %%
# Convert to lowercase

my_sentence.lower()
# Out:
# "it's a wonderful day!"

# %%
# Replace letter or word 

my_sentence.replace("day", "evening")
# Out:
# "It's a wonderful evening!"

# %%
# Count letter or word in string

my_sentence.count("day")
# Out:
# 1

# %%
my_sentence.count("a")
# Out:
# 2

# %%
# Remove whitespace
my_sentence.strip()
# Out:
# "It's a wonderful day!"

# %% [markdown]
# **List**

# %%
list1 = ['a', 'b', 1, "Hello"]
list1
# Out:
# ['a', 'b', 1, 'Hello']

# %%
# Length of the list

len(list1)
# Out:
# 4

# %%
# List operations
# Adding elements in the list, merging two or more lists

list2 =  ['c']
my_list = list1 + list2
my_list
# Out:
# ['a', 'b', 1, 'Hello', 'c']

# %%
my_list * 2
# Out:
# ['a', 'b', 1, 'Hello', 'c', 'a', 'b', 1, 'Hello', 'c']

# %%
# Indexing & slicing
# Indexing starts from 0 from left side & -1 from right side

#selecting item at 1st postion (i.e 0 index)
my_list[0]
# Out:
# 'a'

# %%
# Get index of an item

my_list.index('c')
# Out:
# 4

# %%
# selecting item at last position
my_list[-1]
# Out:
# 'c'

# %%
# Selecting second last element
my_list[-2]
# Out:
# 'Hello'

# %%
# Selecting items at index 0 & upto 2
my_list[0:3]
# Out:
# ['a', 'b', 1]

# %%
# Selecting items after index 0
my_list[1:]
# Out:
# ['b', 1, 'Hello', 'c']

# %%
# Selecting items before index 4
my_list[:4]
# Out:
# ['a', 'b', 1, 'Hello']

# %%
# Copy list
my_list[:]
# Out:
# ['a', 'b', 1, 'Hello', 'c']

# %%
# Removing item from the list using remove, del & pop functions

#If you know exact value of your item, use remove to delete it
# Removing'a'

list1.remove('a')
list1
# Out:
# ['b', 1, 'Hello']

# %%
# If you know position (index) of the item to be removed, use del
# Remove last item from the list1

del(list1[-1])
list1
# Out:
# ['b', 1]

# %%
# Pop removes item by position (index)
list1.pop(1)
list1
# Out:
# ['b']

# %%
# Count items in the list
 my_list.count('a')
# Out:
# 1

# %%
# Add an item at the last position

my_list.append('d')
my_list
# Out:
# ['a', 'b', 1, 'Hello', 'c', 'd']

# %%
# Add amultiple items in the list
my_list.extend(['e', 'f'])
my_list
# Out:
# ['a', 'b', 1, 'Hello', 'c', 'd', 'e', 'f']

# %%
# Add an item at a particular positon
my_list.insert(3, 2)
my_list
# Out:
# ['a', 'b', 1, 2, 'Hello', 'c', 'd', 'e', 'f']

# %%
# Reassign an item in th list
my_list[4] = 3
my_list
# Out:
# ['a', 'b', 1, 2, 3, 'c', 'd', 'e', 'f']

# %%
# Sort the list
my_list2 = ['A', 'B', 'D', 'E' ,'F', 'C']
my_list2.sort()
my_list2
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
# using sorted () function to sort
sorted(my_list2)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F']

# %%
# Check if an element in the list

1 in my_list
# Out:
# True

# %%
2 in my_list2
# Out:
# False

# %%
# Find maximum & minimum

A = [1, 100, 2, 40, 50, 66, 81]

max(A)
# Out:
# 100

# %%
min(A)
# Out:
# 1
